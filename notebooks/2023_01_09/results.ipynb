# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ic.report import show_report

# %%
PREVIOUS_PATH = '../../data/2022_08_01/metrics'
NEW_PATH = '../../data/2023_01_09/metrics'
ALGOS = [
    (PREVIOUS_PATH, 'HoeffdingTree'), 
    (PREVIOUS_PATH, 'Bagging'), 
    (PREVIOUS_PATH, 'ADWINBagging'), 
    (PREVIOUS_PATH, 'KNN'), 
    (PREVIOUS_PATH, 'KNNv2'),
    (NEW_PATH, 'SVM'),
    (NEW_PATH, 'SVM_SGD'),
]
METRICS = ['accuracy', 'recall', 'precision', 'f1']

# %%
show_report('Tuesday-WorkingHours', ALGOS, METRICS)
# Out:
# <h1>Tuesday-WorkingHours</h1>
# <h2>accuracy</h2>
# <h2>recall</h2>
# <h2>precision</h2>
# <h2>f1</h2>
# <hr/>

# %%
show_report('Wednesday-workingHours', ALGOS, METRICS)
# Out:
# <h1>Wednesday-workingHours</h1>
# <h2>accuracy</h2>
# <h2>recall</h2>
# <h2>precision</h2>
# <h2>f1</h2>
# <hr/>

# %%
show_report('Thursday-WorkingHours-Morning-WebAttacks', ALGOS, METRICS)
# Out:
# <h1>Thursday-WorkingHours-Morning-WebAttacks</h1>
# <h2>accuracy</h2>
# <h2>recall</h2>
# <h2>precision</h2>
# <h2>f1</h2>
# <hr/>

# %%
show_report('Friday-WorkingHours-Morning', ALGOS, METRICS)
# Out:
# <h1>Friday-WorkingHours-Morning</h1>
# <h2>accuracy</h2>
# <h2>recall</h2>
# <h2>precision</h2>
# <h2>f1</h2>
# <hr/>

# %%
show_report('Friday-WorkingHours-Afternoon-PortScan', ALGOS, METRICS)
# Out:
# <h1>Friday-WorkingHours-Afternoon-PortScan</h1>
# <h2>accuracy</h2>
# <h2>recall</h2>
# <h2>precision</h2>
# <h2>f1</h2>
# <hr/>

# %%
show_report('Friday-WorkingHours-Afternoon-DDos', ALGOS, METRICS)
# Out:
# <h1>Friday-WorkingHours-Afternoon-DDos</h1>
# <h2>accuracy</h2>
# <h2>recall</h2>
# <h2>precision</h2>
# <h2>f1</h2>
# <hr/>
